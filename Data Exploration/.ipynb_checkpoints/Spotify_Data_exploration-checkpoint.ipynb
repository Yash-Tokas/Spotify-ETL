# %%
# !pip install spotipy    # this is a spotify python package. You need this to access the spotify web API.
# Out:
# Requirement already satisfied: spotipy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (2024.8.30)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd  
# Import the Spotipy library, which is used to interact with the Spotify Web API.  
# Import `SpotifyClientCredentials` for authentication using client credentials flow.  
# Import pandas (`pd`) to store and manipulate the retrieved Spotify data in a structured format, such as a DataFrame.

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="<your_client_id>", client_secret="<your_client_secret>")
# This above line initializes client credentials authentication for Spotify API access using the Spotipy library.
# Create a `SpotifyClientCredentials` object for authentication.  
# - `client_id` and `client_secret` are required credentials for accessing the Spotify Web API.  
# - This authentication method allows access to public Spotify data without user login.  
# - The `client_credentials_manager` is used to authenticate API requests securely.

# %%
# Create a Spotify object to extract data.  
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)  

# This line initializes a Spotipy instance, enabling interaction with the Spotify Web API.  
# It uses client credentials authentication, allowing access to Spotify's data without user login.

# %%
playlist_link = "https://open.spotify.com/playlist/34NbomaTu7YuOYnky8nLXL"  

# We are primarily interested in extracting the playlist ID from the URL.  
# In this case, the playlist ID is "34NbomaTu7YuOYnky8nLXL".

# %%
playlist_id = playlist_link.split("/")[-1]  

# Extract the playlist ID from the URL by splitting the string at each "/" and selecting the last part.  
# This ID is required to interact with the Spotify API.  
# It can be passed as a parameter to functions that require a playlist ID to fetch playlist details.

# %%
data = sp.playlist_items(playlist_id)  

# Fetch all the items (songs and their details) from the specified Spotify playlist.  
# The `playlist_items` function takes the playlist ID as input and retrieves metadata,  
# including track names, artists, albums, and other details.  
# The retrieved data is stored in the `data` variable as a dictionary.

# %%
# The retrieved data is stored as a dictionary, where all song-related information is inside the `items` key.  
# `data['items']` contains a list of dictionaries, with each dictionary representing a track in the playlist.  
# Each track dictionary includes details such as track name, artist, album, and other metadata.  
data['items']
# Out:
# [{'added_at': '2024-10-04T14:54:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#     'id': '10FLjwfpbxLmW8c25Xyc2N',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#       'width': 64}],
#     'name': 'Die With A Smile',
#     'release_date': '2024-08-16',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 251667,
#    'external_ids': {'isrc': 'USUM72409273'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#    'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#    'id': '2plbrEY59IikOBgBGLjaoe',
#    'name': 'Die With A Smile',
#    'popularity': 96,
#    'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-12-01T23:23:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/2IYQwwgxgOIn7t3iF6ufFD',
#     'id': '2IYQwwgxgOIn7t3iF6ufFD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27336032cb4acd9df050bc2e197',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0236032cb4acd9df050bc2e197',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485136032cb4acd9df050bc2e197',
#       'width': 64}],
#     'name': 'APT.',
#     'release_date': '2024-10-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:2IYQwwgxgOIn7t3iF6ufFD',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eVa5w3URK5duf6eyVDbu9'},
#       'href': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9',
#       'id': '3eVa5w3URK5duf6eyVDbu9',
#       'name': 'ROSÉ',
#       'type': 'artist',
#       'uri': 'spotify:artist:3eVa5w3URK5duf6eyVDbu9'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eVa5w3URK5duf6eyVDbu9'},
#      'href': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9',
#      'id': '3eVa5w3URK5duf6eyVDbu9',
#      'name': 'ROSÉ',
#      'type': 'artist',
#      'uri': 'spotify:artist:3eVa5w3URK5duf6eyVDbu9'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 169917,
#    'external_ids': {'isrc': 'USAT22409172'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5vNRhkKd0yEAg8suGBpjeY'},
#    'href': 'https://api.spotify.com/v1/tracks/5vNRhkKd0yEAg8suGBpjeY',
#    'id': '5vNRhkKd0yEAg8suGBpjeY',
#    'name': 'APT.',
#    'popularity': 91,
#    'uri': 'spotify:track:5vNRhkKd0yEAg8suGBpjeY',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-05-08T21:18:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/5quMTd5zeI9yW5UDua8wS4',
#     'id': '5quMTd5zeI9yW5UDua8wS4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273659cd4673230913b3918e0d5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02659cd4673230913b3918e0d5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851659cd4673230913b3918e0d5',
#       'width': 64}],
#     'name': 'Espresso',
#     'release_date': '2024-04-12',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5quMTd5zeI9yW5UDua8wS4',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#       'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#       'id': '74KM79TiuVKeVCqs8QtB0B',
#       'name': 'Sabrina Carpenter',
#       'type': 'artist',
#       'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#      'href': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B',
#      'id': '74KM79TiuVKeVCqs8QtB0B',
#      'name': 'Sabrina Carpenter',
#      'type': 'artist',
#      'uri': 'spotify:artist:74KM79TiuVKeVCqs8QtB0B'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 175459,
#    'external_ids': {'isrc': 'USUM72403305'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2qSkIjg1o9h3YT9RAgYN75'},
#    'href': 'https://api.spotify.com/v1/tracks/2qSkIjg1o9h3YT9RAgYN75',
#    'id': '2qSkIjg1o9h3YT9RAgYN75',
#    'name': 'Espresso',
#    'popularity': 84,
#    'uri': 'spotify:track:2qSkIjg1o9h3YT9RAgYN75',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-05-08T21:18:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/5EYKrEDnKhhcNxGedaRQeK',
#     'id': '5EYKrEDnKhhcNxGedaRQeK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738b58d20f1b77295730db15b4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028b58d20f1b77295730db15b4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518b58d20f1b77295730db15b4',
#       'width': 64}],
#     'name': 'eternal sunshine',
#     'release_date': '2024-03-08',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5EYKrEDnKhhcNxGedaRQeK',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5EYKrEDnKhhcNxGedaRQeK'},
#     'total_tracks': 13},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'disc_number': 1,
#    'track_number': 10,
#    'duration_ms': 228639,
#    'external_ids': {'isrc': 'USUM72317276'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/51ZQ1vr10ffzbwIjDCwqm4'},
#    'href': 'https://api.spotify.com/v1/tracks/51ZQ1vr10ffzbwIjDCwqm4',
#    'id': '51ZQ1vr10ffzbwIjDCwqm4',
#    'name': "we can't be friends (wait for your love)",
#    'popularity': 83,
#    'uri': 'spotify:track:51ZQ1vr10ffzbwIjDCwqm4',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-05-08T21:18:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/1Mo4aZ8pdj6L1jx8zSwJnt',
#     'id': '1Mo4aZ8pdj6L1jx8zSwJnt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735076e4160d018e378f488c33',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025076e4160d018e378f488c33',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515076e4160d018e378f488c33',
#       'width': 64}],
#     'name': 'THE TORTURED POETS DEPARTMENT',
#     'release_date': '2024-04-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:1Mo4aZ8pdj6L1jx8zSwJnt',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1Mo4aZ8pdj6L1jx8zSwJnt'},
#     'total_tracks': 16},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#      'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#      'id': '246dkjvS1zLTtiykXe5h60',
#      'name': 'Post Malone',
#      'type': 'artist',
#      'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 228965,
#    'external_ids': {'isrc': 'USUG12401028'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2OzhQlSqBEmt7hmkYxfT6m'},
#    'href': 'https://api.spotify.com/v1/tracks/2OzhQlSqBEmt7hmkYxfT6m',
#    'id': '2OzhQlSqBEmt7hmkYxfT6m',
#    'name': 'Fortnight (feat. Post Malone)',
#    'popularity': 79,
#    'uri': 'spotify:track:2OzhQlSqBEmt7hmkYxfT6m',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-10-04T14:55:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/7aJuG4TFXa2hmE4z1yxc3n',
#     'id': '7aJuG4TFXa2hmE4z1yxc3n',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27371d62ea7ea8a5be92d3c1f62',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0271d62ea7ea8a5be92d3c1f62',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485171d62ea7ea8a5be92d3c1f62',
#       'width': 64}],
#     'name': 'HIT ME HARD AND SOFT',
#     'release_date': '2024-05-17',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:7aJuG4TFXa2hmE4z1yxc3n',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 210373,
#    'external_ids': {'isrc': 'USUM72401994'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB'},
#    'href': 'https://api.spotify.com/v1/tracks/6dOtVTDdiauQNBQEDOtlAB',
#    'id': '6dOtVTDdiauQNBQEDOtlAB',
#    'name': 'BIRDS OF A FEATHER',
#    'popularity': 94,
#    'uri': 'spotify:track:6dOtVTDdiauQNBQEDOtlAB',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-05-08T21:18:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/7I0tjwFtxUwBC1vgyeMAax',
#     'id': '7I0tjwFtxUwBC1vgyeMAax',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f429549123dbe8552764ba1d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f429549123dbe8552764ba1d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f429549123dbe8552764ba1d',
#       'width': 64}],
#     'name': 'Flowers',
#     'release_date': '2023-01-13',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:7I0tjwFtxUwBC1vgyeMAax',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#       'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#       'id': '5YGY8feqx7naU7z4HrwZM6',
#       'name': 'Miley Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#      'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#      'id': '5YGY8feqx7naU7z4HrwZM6',
#      'name': 'Miley Cyrus',
#      'type': 'artist',
#      'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 200454,
#    'external_ids': {'isrc': 'USSM12209777'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn'},
#    'href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#    'id': '0yLdNVWF3Srea0uzk55zFn',
#    'name': 'Flowers',
#    'popularity': 26,
#    'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-05-08T21:18:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/3Uq1jNGnD412ZvCb6j2DKV',
#     'id': '3Uq1jNGnD412ZvCb6j2DKV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27350a1691fbbfb693a5171d600',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0250a1691fbbfb693a5171d600',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485150a1691fbbfb693a5171d600',
#       'width': 64}],
#     'name': 'Gloria',
#     'release_date': '2023-01-27',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:3Uq1jNGnD412ZvCb6j2DKV',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Uq1jNGnD412ZvCb6j2DKV'},
#     'total_tracks': 13},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#      'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#      'id': '2wY79sveU1sp5g7SokKOiI',
#      'name': 'Sam Smith',
#      'type': 'artist',
#      'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Xt3RrJMFv5SZkCfUE8C1J'},
#      'href': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J',
#      'id': '3Xt3RrJMFv5SZkCfUE8C1J',
#      'name': 'Kim Petras',
#      'type': 'artist',
# ...
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/3VQkNrG74QPY4rHBPoyZYZ',
#     'id': '3VQkNrG74QPY4rHBPoyZYZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737f5a318e3ff35defa8d0e4af',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027f5a318e3ff35defa8d0e4af',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517f5a318e3ff35defa8d0e4af',
#       'width': 64}],
#     'name': 'SOS Deluxe: LANA',
#     'release_date': '2024-12-20',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:3VQkNrG74QPY4rHBPoyZYZ',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#       'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#       'id': '7tYKF4w9nC0nq9CsPZTHyP',
#       'name': 'SZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3VQkNrG74QPY4rHBPoyZYZ'},
#     'total_tracks': 38},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#      'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#      'id': '7tYKF4w9nC0nq9CsPZTHyP',
#      'name': 'SZA',
#      'type': 'artist',
#      'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#    'disc_number': 1,
#    'track_number': 5,
#    'duration_ms': 180746,
#    'external_ids': {'isrc': 'USRC12403826'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3U3hFkMr0Q90pD24EkE3Pr'},
#    'href': 'https://api.spotify.com/v1/tracks/3U3hFkMr0Q90pD24EkE3Pr',
#    'id': '3U3hFkMr0Q90pD24EkE3Pr',
#    'name': 'BMF',
#    'popularity': 85,
#    'uri': 'spotify:track:3U3hFkMr0Q90pD24EkE3Pr',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-01-12T16:05:26Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/3ZZlKPrWKSVI28zT3AGLQB',
#     'id': '3ZZlKPrWKSVI28zT3AGLQB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732aab4ea84f431ad7d92fecbb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022aab4ea84f431ad7d92fecbb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512aab4ea84f431ad7d92fecbb',
#       'width': 64}],
#     'name': 'Ma Meilleure Ennemie (from the series Arcane League of Legends)',
#     'release_date': '2024-11-23',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:3ZZlKPrWKSVI28zT3AGLQB',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5j4HeCoUlzhfWtjAfM1acR'},
#       'href': 'https://api.spotify.com/v1/artists/5j4HeCoUlzhfWtjAfM1acR',
#       'id': '5j4HeCoUlzhfWtjAfM1acR',
#       'name': 'Stromae',
#       'type': 'artist',
#       'uri': 'spotify:artist:5j4HeCoUlzhfWtjAfM1acR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#       'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#       'id': '6e3pZKXUxrPfnUPJ960Hd9',
#       'name': 'Pomme',
#       'type': 'artist',
#       'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/57nPqD7z62gDdq37US9XJR'},
#       'href': 'https://api.spotify.com/v1/artists/57nPqD7z62gDdq37US9XJR',
#       'id': '57nPqD7z62gDdq37US9XJR',
#       'name': 'Arcane',
#       'type': 'artist',
#       'uri': 'spotify:artist:57nPqD7z62gDdq37US9XJR'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3ZZlKPrWKSVI28zT3AGLQB'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5j4HeCoUlzhfWtjAfM1acR'},
#      'href': 'https://api.spotify.com/v1/artists/5j4HeCoUlzhfWtjAfM1acR',
#      'id': '5j4HeCoUlzhfWtjAfM1acR',
#      'name': 'Stromae',
#      'type': 'artist',
#      'uri': 'spotify:artist:5j4HeCoUlzhfWtjAfM1acR'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6e3pZKXUxrPfnUPJ960Hd9'},
#      'href': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9',
#      'id': '6e3pZKXUxrPfnUPJ960Hd9',
#      'name': 'Pomme',
#      'type': 'artist',
#      'uri': 'spotify:artist:6e3pZKXUxrPfnUPJ960Hd9'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/57nPqD7z62gDdq37US9XJR'},
#      'href': 'https://api.spotify.com/v1/artists/57nPqD7z62gDdq37US9XJR',
#      'id': '57nPqD7z62gDdq37US9XJR',
#      'name': 'Arcane',
#      'type': 'artist',
#      'uri': 'spotify:artist:57nPqD7z62gDdq37US9XJR'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 147973,
#    'external_ids': {'isrc': 'USA2P2459602'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4lriIG2vNqwDWzOj2I9rtj'},
#    'href': 'https://api.spotify.com/v1/tracks/4lriIG2vNqwDWzOj2I9rtj',
#    'id': '4lriIG2vNqwDWzOj2I9rtj',
#    'name': 'Ma Meilleure Ennemie (from the series Arcane League of Legends)',
#    'popularity': 79,
#    'uri': 'spotify:track:4lriIG2vNqwDWzOj2I9rtj',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-01-12T16:16:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#    'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#    'id': '313odiyd72vqxinsh4grr4wqqfpa',
#    'type': 'user',
#    'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/7nacKlk586eLRBSIsrk9DB',
#     'id': '7nacKlk586eLRBSIsrk9DB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731a0323cc23419360a34a3ace',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021a0323cc23419360a34a3ace',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511a0323cc23419360a34a3ace',
#       'width': 64}],
#     'name': "I've Tried Everything But Therapy (Part 1)",
#     'release_date': '2023-09-15',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:7nacKlk586eLRBSIsrk9DB',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/33qOK5uJ8AR2xuQQAhHump'},
#       'href': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump',
#       'id': '33qOK5uJ8AR2xuQQAhHump',
#       'name': 'Teddy Swims',
#       'type': 'artist',
#       'uri': 'spotify:artist:33qOK5uJ8AR2xuQQAhHump'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7nacKlk586eLRBSIsrk9DB'},
#     'total_tracks': 10},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/33qOK5uJ8AR2xuQQAhHump'},
#      'href': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump',
#      'id': '33qOK5uJ8AR2xuQQAhHump',
#      'name': 'Teddy Swims',
#      'type': 'artist',
#      'uri': 'spotify:artist:33qOK5uJ8AR2xuQQAhHump'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 212648,
#    'external_ids': {'isrc': 'USWB12302870'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3dj4wgM3cPeuLwMNHDuBon'},
#    'href': 'https://api.spotify.com/v1/tracks/3dj4wgM3cPeuLwMNHDuBon',
#    'id': '3dj4wgM3cPeuLwMNHDuBon',
#    'name': 'The Door',
#    'popularity': 83,
#    'uri': 'spotify:track:3dj4wgM3cPeuLwMNHDuBon',
#    'is_local': False},
#   'video_thumbnail': {'url': None}}]

# %%
# Access the first item in the `items` list, which represents the first track in the playlist.  
# This is a dictionary containing details about the track, such as its name, artist, album, and other metadata.  
data['items'][0]
# Out:
# {'added_at': '2024-10-04T14:54:56Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/313odiyd72vqxinsh4grr4wqqfpa'},
#   'href': 'https://api.spotify.com/v1/users/313odiyd72vqxinsh4grr4wqqfpa',
#   'id': '313odiyd72vqxinsh4grr4wqqfpa',
#   'type': 'user',
#   'uri': 'spotify:user:313odiyd72vqxinsh4grr4wqqfpa'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#    'id': '10FLjwfpbxLmW8c25Xyc2N',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45',
#      'width': 64}],
#    'name': 'Die With A Smile',
#    'release_date': '2024-08-16',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#    'total_tracks': 1},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#     'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#     'id': '0du5cEVh5yTK9QJze8zA0C',
#     'name': 'Bruno Mars',
#     'type': 'artist',
#     'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 251667,
#   'external_ids': {'isrc': 'USUM72409273'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#   'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#   'id': '2plbrEY59IikOBgBGLjaoe',
#   'name': 'Die With A Smile',
#   'popularity': 96,
#   'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
len(data['items'])   # this will give the number of songs in the playlist.
# Out:
# 51

# %%
# The variable `data` contains all the information retrieved from the URL.  
# All songs and their details are stored inside the `items` list.  
# To access the album ID of the first track in the playlist:  
# - We go to `data['items'][0]`, which represents the first song entry (a dictionary).  
# - Inside it, we access the `track` key, which contains track-related details.  
# - Within `track`, we navigate to the `album` key, which holds the album information.  
# - Finally, from the `album` dictionary, we retrieve the value of the `id` key.  
data['items'][0]['track']['album']['id']
# Out:
# '10FLjwfpbxLmW8c25Xyc2N'

# %%
# Retrieve the name of the album for the first track in the playlist.  
# - `data['items'][0]` accesses the first track entry in the playlist.  
# - `['track']` navigates to the track details.  
# - `['album']` retrieves the album information associated with the track.  
# - `['name']` fetches the album name.  
data['items'][0]['track']['album']['name']
# Out:
# 'Die With A Smile'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-16'

# %%
# Extract album details for all songs in the playlist.  
# - Create an empty list `album_list` to store album information for each track.  
# - Loop through `data['items']`, where each entry represents a song in the playlist.  
# - Extract relevant album details such as `id`, `name`, `release_date`, `total_tracks`, and `album_url`.  
# - Store these details in a dictionary and append it to `album_list`.  

album_list = []

for row in data['items']:  
    # Extract album details for the current track.  
    album_id = row['track']['album']['id']  
    album_name = row['track']['album']['name']  
    album_release_date = row['track']['album']['release_date']  
    album_total_tracks = row['track']['album']['total_tracks']  
    album_url = row['track']['album']['external_urls']['spotify']  

    # Create a dictionary to store extracted album details.  
    album_elements = {
        'album_id': album_id, 
        'name': album_name, 
        'release_date': album_release_date, 
        'total_tracks': album_total_tracks, 
        'url': album_url
    }  

    # Append the dictionary to the album list.  
    album_list.append(album_elements)  

# The `album_list` now contains album details for all tracks in the playlist.  
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '2IYQwwgxgOIn7t3iF6ufFD',
#   'name': 'APT.',
#   'release_date': '2024-10-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'name': 'Espresso',
#   'release_date': '2024-04-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '5EYKrEDnKhhcNxGedaRQeK',
#   'name': 'eternal sunshine',
#   'release_date': '2024-03-08',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5EYKrEDnKhhcNxGedaRQeK'},
#  {'album_id': '1Mo4aZ8pdj6L1jx8zSwJnt',
#   'name': 'THE TORTURED POETS DEPARTMENT',
#   'release_date': '2024-04-18',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1Mo4aZ8pdj6L1jx8zSwJnt'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '7I0tjwFtxUwBC1vgyeMAax',
#   'name': 'Flowers',
#   'release_date': '2023-01-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'},
#  {'album_id': '3Uq1jNGnD412ZvCb6j2DKV',
#   'name': 'Gloria',
#   'release_date': '2023-01-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/3Uq1jNGnD412ZvCb6j2DKV'},
#  {'album_id': '04PEOM6kIEeq9lRp1asNP2',
#   'name': 'I Ain’t Worried (Music From The Motion Picture "Top Gun: Maverick")',
#   'release_date': '2022-05-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/04PEOM6kIEeq9lRp1asNP2'},
#  {'album_id': '1Q9SnHWPNEjVM0LrBFvJ1q',
#   'name': 'Bones',
#   'release_date': '2022-03-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Q9SnHWPNEjVM0LrBFvJ1q'},
#  {'album_id': '18CtLoAMTr7F8ngtuM6D8i',
#   'name': 'Until I Found You',
#   'release_date': '2021-09-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/18CtLoAMTr7F8ngtuM6D8i'},
#  {'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'name': 'GUTS',
#   'release_date': '2023-09-08',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/1xJHno7SmdVtZAtXbdbDZp'},
#  {'album_id': '62g7jm7YqkuQOhfhFpDQXC',
#   'name': 'Make You Mine',
#   'release_date': '2024-02-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/62g7jm7YqkuQOhfhFpDQXC'},
#  {'album_id': '7jaSNQUBJbvfbZHLNFrV7P',
#   'name': 'BORN PINK',
#   'release_date': '2022-09-16',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/7jaSNQUBJbvfbZHLNFrV7P'},
#  {'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'name': "I've Tried Everything But Therapy (Part 1)",
#   'release_date': '2023-09-15',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7nacKlk586eLRBSIsrk9DB'},
#  {'album_id': '3cptxwPFf3Ioj7I3AVX3mp',
#   'name': 'How Do I Say Goodbye',
#   'release_date': '2022-08-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3cptxwPFf3Ioj7I3AVX3mp'},
#  {'album_id': '0hBRqPYPXhr1RkTDG3n4Mk',
#   'name': 'The Secret of Us (Deluxe)',
#   'release_date': '2024-10-18',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/0hBRqPYPXhr1RkTDG3n4Mk'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'name': 'MUSE',
#   'release_date': '2024-07-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'name': 'greedy',
#   'release_date': '2023-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '1Mo92916G2mmG7ajpmSVrc',
#   'name': 'Radical Optimism',
#   'release_date': '2024-05-03',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/1Mo92916G2mmG7ajpmSVrc'},
#  {'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'name': 'Starboy',
#   'release_date': '2016-11-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  {'album_id': '44CdsgXhU5R2esprq0tf43',
#   'name': 'Angel Baby',
#   'release_date': '2021-09-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/44CdsgXhU5R2esprq0tf43'},
#  {'album_id': '3HHNR44YbP7XogMVwzbodx',
#   'name': 'Twelve Carat Toothache',
#   'release_date': '2022-06-03',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/3HHNR44YbP7XogMVwzbodx'},
#  {'album_id': '3Zzv75PyROH6AMeXN1Yr1h',
#   'name': 'Lift Me Up (From Black Panther: Wakanda Forever - Music From and Inspired By)',
#   'release_date': '2022-10-28',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/3Zzv75PyROH6AMeXN1Yr1h'},
#  {'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'name': 'Fireworks & Rollerblades',
#   'release_date': '2024-04-05',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/168CdR21lfn0TTyw1Pkdcm'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'name': 'SOS',
#   'release_date': '2022-12-08',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '47ivZmuVI0HboDeCl6uOZv',
#   'name': 'All My Heroes',
#   'release_date': '2020-07-31',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/47ivZmuVI0HboDeCl6uOZv'},
#  {'album_id': '3omkMn8vbTKOebb9ABbqyb',
#   'name': 'Escapism. / The Thrill Is Gone.',
#   'release_date': '2022-10-12',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/3omkMn8vbTKOebb9ABbqyb'},
#  {'album_id': '2DoFm78vsYw31kJRzvIP4l',
#   'name': 'Whatever',
#   'release_date': '2024-01-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2DoFm78vsYw31kJRzvIP4l'},
#  {'album_id': '6s84u2TUpR3wdUv4NgKA2j',
#   'name': 'SOUR',
#   'release_date': '2021-05-21',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#  {'album_id': '5kDmlA2g9Y1YCbNo2Ufxlz',
#   'name': "emails i can't send",
#   'release_date': '2022-07-15',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5kDmlA2g9Y1YCbNo2Ufxlz'},
#  {'album_id': '1Mo4aZ8pdj6L1jx8zSwJnt',
#   'name': 'THE TORTURED POETS DEPARTMENT',
#   'release_date': '2024-04-18',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1Mo4aZ8pdj6L1jx8zSwJnt'},
#  {'album_id': '1BaHo66NCQNx6ku0hPn9bR',
#   'name': 'TOO YOUNG TO BE SAD',
#   'release_date': '2021-03-26',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/1BaHo66NCQNx6ku0hPn9bR'},
#  {'album_id': '6jKZplJpy21R5lHaYHHjmZ',
#   'name': 'Narrated For You',
#   'release_date': '2018-11-16',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6jKZplJpy21R5lHaYHHjmZ'},
#  {'album_id': '6lVzd7PgdTCzmN8P9rOA0o',
#   'name': 'Good To Be',
#   'release_date': '2023-10-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6lVzd7PgdTCzmN8P9rOA0o'},
#  {'album_id': '1XsMFyyPhYodMoE8V0SMkl',
#   'name': 'Locksmith',
#   'release_date': '2022-10-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1XsMFyyPhYodMoE8V0SMkl'},
#  {'album_id': '4h7ERA3MzqEh9B3edziLAn',
#   'name': 'labour',
#   'release_date': '2023-03-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4h7ERA3MzqEh9B3edziLAn'},
#  {'album_id': '5HIWDdg3g9CTOtnevKDl1z',
#   'name': 'i like the way you kiss me',
#   'release_date': '2024-03-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5HIWDdg3g9CTOtnevKDl1z'},
#  {'album_id': '4SiEsSExMEqycC1lhRRiOY',
#   'name': 'Jeanie',
#   'release_date': '2024-11-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4SiEsSExMEqycC1lhRRiOY'},
#  {'album_id': '3PlCMwyq6nuQYtoYproV1o',
#   'name': 'Belong Together',
#   'release_date': '2024-02-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3PlCMwyq6nuQYtoYproV1o'},
#  {'album_id': '68mwSgiHv3JF9nrw9feMrt',
#   'name': 'Illusion',
#   'release_date': '2024-04-11',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/68mwSgiHv3JF9nrw9feMrt'},
#  {'album_id': '1fmBMCSSkSlvxyoy1vut2k',
#   'name': 'Saturn',
#   'release_date': '2024-02-22',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/1fmBMCSSkSlvxyoy1vut2k'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': '50ZenUP4O2Q5eCy2NRNvuz',
#   'name': 'Stick Season',
#   'release_date': '2022-10-14',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/50ZenUP4O2Q5eCy2NRNvuz'},
#  {'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'name': 'Good Luck, Babe!',
#   'release_date': '2024-04-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#  {'album_id': '3NpeIWhWsxU7d3XL5KEh39',
#   'name': 'Scared To Start',
#   'release_date': '2024-01-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3NpeIWhWsxU7d3XL5KEh39'},
#  {'album_id': '2Zh6Oz9pR5zYF3vEno5jV5',
#   'name': 'Alibi (Tiësto Remix)',
#   'release_date': '2024-11-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2Zh6Oz9pR5zYF3vEno5jV5'},
#  {'album_id': '3VQkNrG74QPY4rHBPoyZYZ',
#   'name': 'SOS Deluxe: LANA',
#   'release_date': '2024-12-20',
#   'total_tracks': 38,
#   'url': 'https://open.spotify.com/album/3VQkNrG74QPY4rHBPoyZYZ'},
#  {'album_id': '3ZZlKPrWKSVI28zT3AGLQB',
#   'name': 'Ma Meilleure Ennemie (from the series Arcane League of Legends)',
#   'release_date': '2024-11-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3ZZlKPrWKSVI28zT3AGLQB'},
#  {'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'name': "I've Tried Everything But Therapy (Part 1)",
#   'release_date': '2023-09-15',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7nacKlk586eLRBSIsrk9DB'}]

# %%
# Retrieve the name of the first artist of the first track in the playlist.  
# - `data['items'][0]` accesses the first track entry in the playlist.  
# - `['track']` navigates to the track details.  
# - `['artists']` is a list of dictionaries, where each dictionary represents an artist.  
# - Since a track can have multiple artists, `[0]` selects the first artist from the list.  
# - If `[0]` is not specified, it would result in an error because `artists` is a list,  
#   and we need to specify an index to access a dictionary within it.  
# - `['name']` fetches the artist's name from the selected dictionary.  
data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Lady Gaga'

# %%
# Extract artist details for all songs in the playlist.  
# - Create an empty list `artist_list` to store artist information.  
# - Loop through `data['items']`, where each entry represents a song.  
# - Access the `track` key to get track-related details.  
# - Inside `track`, the `artists` key contains a list of dictionaries (each representing an artist).  
# - Iterate through the `artists` list to extract each artist's `id`, `name`, and `external_url`.  
# - Store these details in a dictionary and append it to `artist_list`.  

artist_list = []

for row in data['items']:  
    for key, value in row.items():  
        if key == 'track':  
            for artist in value['artists']:  
                # Extract relevant artist details.  
                artist_dict = {
                    'artist_id': artist['id'],  
                    'name': artist['name'],  
                    'url': artist['href']
                }  

                # Append the dictionary to the artist list.  
                artist_list.append(artist_dict)  

# The `artist_list` now contains details of all artists from the playlist.  
artist_list
# Out:
# [{'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'name': 'ROSÉ',
#   'url': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'name': 'Sabrina Carpenter',
#   'url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'name': 'Ariana Grande',
#   'url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'name': 'Taylor Swift',
#   'url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'name': 'Post Malone',
#   'url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'name': 'Billie Eilish',
#   'url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '5YGY8feqx7naU7z4HrwZM6',
#   'name': 'Miley Cyrus',
#   'url': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6'},
#  {'artist_id': '2wY79sveU1sp5g7SokKOiI',
#   'name': 'Sam Smith',
#   'url': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI'},
#  {'artist_id': '3Xt3RrJMFv5SZkCfUE8C1J',
#   'name': 'Kim Petras',
#   'url': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J'},
#  {'artist_id': '5Pwc4xIPtQLFEnJriah9YJ',
#   'name': 'OneRepublic',
#   'url': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ'},
#  {'artist_id': '53XhwfbYqKCa1cC15pYq2q',
#   'name': 'Imagine Dragons',
#   'url': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q'},
#  {'artist_id': '5XKFrudbV4IiuE5WuTPRmT',
#   'name': 'Stephen Sanchez',
#   'url': 'https://api.spotify.com/v1/artists/5XKFrudbV4IiuE5WuTPRmT'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'name': 'Olivia Rodrigo',
#   'url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '2kRfqPViCqYdSGhYSM9R0Q',
#   'name': 'Madison Beer',
#   'url': 'https://api.spotify.com/v1/artists/2kRfqPViCqYdSGhYSM9R0Q'},
#  {'artist_id': '41MozSoPIsD1dJM0CLPjZF',
#   'name': 'BLACKPINK',
#   'url': 'https://api.spotify.com/v1/artists/41MozSoPIsD1dJM0CLPjZF'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'name': 'Teddy Swims',
#   'url': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '3QSQFmccmX81fWCUSPTS7y',
#   'name': 'Dean Lewis',
#   'url': 'https://api.spotify.com/v1/artists/3QSQFmccmX81fWCUSPTS7y'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'name': 'Gracie Abrams',
#   'url': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'name': 'Jimin',
#   'url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'name': 'Tate McRae',
#   'url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'name': 'Dua Lipa',
#   'url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'name': 'The Weeknd',
#   'url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '3WGpXCj9YhhfX11TToZcXP',
#   'name': 'Troye Sivan',
#   'url': 'https://api.spotify.com/v1/artists/3WGpXCj9YhhfX11TToZcXP'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'name': 'Post Malone',
#   'url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '5cj0lLjcoR7YOSnhnX0Po5',
#   'name': 'Doja Cat',
#   'url': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5'},
#  {'artist_id': '5pKCCKE2ajJHZ9KAiaK11H',
#   'name': 'Rihanna',
#   'url': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'name': 'Benson Boone',
#   'url': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'name': 'SZA',
#   'url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '2DYDFBqoaBP2i9XrTGpOgF',
#   'name': 'Naeleck',
#   'url': 'https://api.spotify.com/v1/artists/2DYDFBqoaBP2i9XrTGpOgF'},
#  {'artist_id': '58obmxGKVKCenZAkACSMgJ',
#   'name': 'Sarah Rebecca',
#   'url': 'https://api.spotify.com/v1/artists/58obmxGKVKCenZAkACSMgJ'},
#  {'artist_id': '5KKpBU5eC2tJDzf0wmlRp2',
#   'name': 'RAYE',
#   'url': 'https://api.spotify.com/v1/artists/5KKpBU5eC2tJDzf0wmlRp2'},
#  {'artist_id': '12Zk1DFhCbHY6v3xep2ZjI',
#   'name': '070 Shake',
#   'url': 'https://api.spotify.com/v1/artists/12Zk1DFhCbHY6v3xep2ZjI'},
#  {'artist_id': '23fqKkggKUBHNkbKtXEls4',
#   'name': 'Kygo',
#   'url': 'https://api.spotify.com/v1/artists/23fqKkggKUBHNkbKtXEls4'},
#  {'artist_id': '4npEfmQ6YuiwW1GpUmaq3F',
#   'name': 'Ava Max',
#   'url': 'https://api.spotify.com/v1/artists/4npEfmQ6YuiwW1GpUmaq3F'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'name': 'Olivia Rodrigo',
#   'url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'name': 'Sabrina Carpenter',
#   'url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'name': 'Taylor Swift',
#   'url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'name': 'Tate McRae',
#   'url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '5IH6FPUwQTxPSXurCrcIov',
#   'name': 'Alec Benjamin',
#   'url': 'https://api.spotify.com/v1/artists/5IH6FPUwQTxPSXurCrcIov'},
#  {'artist_id': '11p2E654TTU8e0nZWBR4AL',
#   'name': 'Mark Ambor',
#   'url': 'https://api.spotify.com/v1/artists/11p2E654TTU8e0nZWBR4AL'},
#  {'artist_id': '0sMAHzxguan2KpnKFZPW2d',
#   'name': 'Sadie Jean',
#   'url': 'https://api.spotify.com/v1/artists/0sMAHzxguan2KpnKFZPW2d'},
#  {'artist_id': '2EXpthNgSeTDeX8nGwxppp',
#   'name': 'Paris Paloma',
#   'url': 'https://api.spotify.com/v1/artists/2EXpthNgSeTDeX8nGwxppp'},
#  {'artist_id': '0PCCGZ0wGLizHt2KZ7hhA2',
#   'name': 'Artemas',
#   'url': 'https://api.spotify.com/v1/artists/0PCCGZ0wGLizHt2KZ7hhA2'},
#  {'artist_id': '1GLtl8uqKmnyCWxHmw9tL4',
#   'name': 'The Kooks',
#   'url': 'https://api.spotify.com/v1/artists/1GLtl8uqKmnyCWxHmw9tL4'},
#  {'artist_id': '4KJ6jujcNPzOyhdNoiNftp',
#   'name': 'lovelytheband',
#   'url': 'https://api.spotify.com/v1/artists/4KJ6jujcNPzOyhdNoiNftp'},
#  {'artist_id': '11p2E654TTU8e0nZWBR4AL',
#   'name': 'Mark Ambor',
#   'url': 'https://api.spotify.com/v1/artists/11p2E654TTU8e0nZWBR4AL'},
#  {'artist_id': '6M2wZ9GZgrQXHCFfjv46we',
#   'name': 'Dua Lipa',
#   'url': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'name': 'SZA',
#   'url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'name': 'Taylor Swift',
#   'url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'name': 'Harry Styles',
#   'url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '2RQXRUsr4IW1f3mKyKsy4B',
#   'name': 'Noah Kahan',
#   'url': 'https://api.spotify.com/v1/artists/2RQXRUsr4IW1f3mKyKsy4B'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'name': 'Chappell Roan',
#   'url': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '4j96cMcT8GRi11qbvo1cLQ',
#   'name': 'Michael Marcagi',
#   'url': 'https://api.spotify.com/v1/artists/4j96cMcT8GRi11qbvo1cLQ'},
#  {'artist_id': '5MraexJKZDrQYzS98kNwie',
#   'name': 'Sevdaliza',
#   'url': 'https://api.spotify.com/v1/artists/5MraexJKZDrQYzS98kNwie'},
#  {'artist_id': '1QsdzIKkTT5gDFj8GB1cIX',
#   'name': 'Yseult',
#   'url': 'https://api.spotify.com/v1/artists/1QsdzIKkTT5gDFj8GB1cIX'},
#  {'artist_id': '2o5jDhtHVPhrJdv3cEQ99Z',
#   'name': 'Tiësto',
#   'url': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z'},
#  {'artist_id': '6tzRZ39aZlNqlUzQlkuhDV',
#   'name': 'Pabllo Vittar',
#   'url': 'https://api.spotify.com/v1/artists/6tzRZ39aZlNqlUzQlkuhDV'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'name': 'SZA',
#   'url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '5j4HeCoUlzhfWtjAfM1acR',
#   'name': 'Stromae',
#   'url': 'https://api.spotify.com/v1/artists/5j4HeCoUlzhfWtjAfM1acR'},
#  {'artist_id': '6e3pZKXUxrPfnUPJ960Hd9',
#   'name': 'Pomme',
#   'url': 'https://api.spotify.com/v1/artists/6e3pZKXUxrPfnUPJ960Hd9'},
#  {'artist_id': '57nPqD7z62gDdq37US9XJR',
#   'name': 'Arcane',
#   'url': 'https://api.spotify.com/v1/artists/57nPqD7z62gDdq37US9XJR'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'name': 'Teddy Swims',
#   'url': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump'}]

# %%
data['items'][4]['track']['name']
# Out:
# 'Fortnight (feat. Post Malone)'

# %%
# Extract song details for all tracks in the playlist.  
# - Create an empty list `song_list` to store song information.  
# - Loop through `data['items']`, where each entry represents a song.  
# - Extract relevant details:  
#   - `song_id`: Unique identifier for the track.  
#   - `song_name`: Name of the track.  
#   - `song_duration`: Track duration in milliseconds.  
#   - `song_url`: Spotify URL for the track.  
#   - `song_popularity`: Popularity score of the track (0-100).  
#   - `song_added`: Timestamp of when the song was added to the playlist.  
#   - `album_id`: The album ID to which the song belongs.  
#   - `artist_id`: The ID of the first artist (assuming multiple artists, only the first is taken).  
# - Store these details in a dictionary and append it to `song_list`.  

song_list = []

for row in data['items']:  
    song_id = row['track']['id']  
    song_name = row['track']['name']  
    song_duration = row['track']['duration_ms']  
    song_url = row['track']['external_urls']['spotify']  
    song_popularity = row['track']['popularity']  
    song_added = row['added_at']  
    album_id = row['track']['album']['id']  
    artist_id = row['track']['album']['artists'][0]['id']  # Extracting the first artist's ID  

    # Create a dictionary for song details.  
    song_element = {
        'song_id': song_id,  
        'song_name': song_name,  
        'duration_ms': song_duration,  
        'url': song_url,  
        'popularity': song_popularity,  
        'song_added': song_added,  
        'album_id': album_id,  
        'artist_id': artist_id  
    }  

    # Append the dictionary to the song list.  
    song_list.append(song_element)  

# The `song_list` now contains details of all songs in the playlist.  
song_list
# Out:
# [{'song_id': '2plbrEY59IikOBgBGLjaoe',
#   'song_name': 'Die With A Smile',
#   'duration_ms': 251667,
#   'url': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe',
#   'popularity': 96,
#   'song_added': '2024-10-04T14:54:56Z',
#   'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '5vNRhkKd0yEAg8suGBpjeY',
#   'song_name': 'APT.',
#   'duration_ms': 169917,
#   'url': 'https://open.spotify.com/track/5vNRhkKd0yEAg8suGBpjeY',
#   'popularity': 91,
#   'song_added': '2024-12-01T23:23:05Z',
#   'album_id': '2IYQwwgxgOIn7t3iF6ufFD',
#   'artist_id': '3eVa5w3URK5duf6eyVDbu9'},
#  {'song_id': '2qSkIjg1o9h3YT9RAgYN75',
#   'song_name': 'Espresso',
#   'duration_ms': 175459,
#   'url': 'https://open.spotify.com/track/2qSkIjg1o9h3YT9RAgYN75',
#   'popularity': 84,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '51ZQ1vr10ffzbwIjDCwqm4',
#   'song_name': "we can't be friends (wait for your love)",
#   'duration_ms': 228639,
#   'url': 'https://open.spotify.com/track/51ZQ1vr10ffzbwIjDCwqm4',
#   'popularity': 83,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '5EYKrEDnKhhcNxGedaRQeK',
#   'artist_id': '66CXWjxzNUsdJxJ2JdwvnR'},
#  {'song_id': '2OzhQlSqBEmt7hmkYxfT6m',
#   'song_name': 'Fortnight (feat. Post Malone)',
#   'duration_ms': 228965,
#   'url': 'https://open.spotify.com/track/2OzhQlSqBEmt7hmkYxfT6m',
#   'popularity': 79,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1Mo4aZ8pdj6L1jx8zSwJnt',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'duration_ms': 210373,
#   'url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'popularity': 94,
#   'song_added': '2024-10-04T14:55:25Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '0yLdNVWF3Srea0uzk55zFn',
#   'song_name': 'Flowers',
#   'duration_ms': 200454,
#   'url': 'https://open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn',
#   'popularity': 26,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '7I0tjwFtxUwBC1vgyeMAax',
#   'artist_id': '5YGY8feqx7naU7z4HrwZM6'},
#  {'song_id': '0NZPBYD5qbEWRs3PrGiRkT',
#   'song_name': 'Unholy (feat. Kim Petras)',
#   'duration_ms': 156943,
#   'url': 'https://open.spotify.com/track/0NZPBYD5qbEWRs3PrGiRkT',
#   'popularity': 69,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '3Uq1jNGnD412ZvCb6j2DKV',
#   'artist_id': '2wY79sveU1sp5g7SokKOiI'},
#  {'song_id': '4h9wh7iOZ0GGn8QVp4RAOB',
#   'song_name': "I Ain't Worried",
#   'duration_ms': 148485,
#   'url': 'https://open.spotify.com/track/4h9wh7iOZ0GGn8QVp4RAOB',
#   'popularity': 77,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '04PEOM6kIEeq9lRp1asNP2',
#   'artist_id': '5Pwc4xIPtQLFEnJriah9YJ'},
#  {'song_id': '0HqZX76SFLDz2aW8aiqi7G',
#   'song_name': 'Bones',
#   'duration_ms': 165264,
#   'url': 'https://open.spotify.com/track/0HqZX76SFLDz2aW8aiqi7G',
#   'popularity': 71,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1Q9SnHWPNEjVM0LrBFvJ1q',
#   'artist_id': '53XhwfbYqKCa1cC15pYq2q'},
#  {'song_id': '0T5iIrXA4p5GsubkhuBIKV',
#   'song_name': 'Until I Found You',
#   'duration_ms': 177720,
#   'url': 'https://open.spotify.com/track/0T5iIrXA4p5GsubkhuBIKV',
#   'popularity': 73,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '18CtLoAMTr7F8ngtuM6D8i',
#   'artist_id': '5XKFrudbV4IiuE5WuTPRmT'},
#  {'song_id': '1kuGVB7EU95pJObxwvfwKS',
#   'song_name': 'vampire',
#   'duration_ms': 219724,
#   'url': 'https://open.spotify.com/track/1kuGVB7EU95pJObxwvfwKS',
#   'popularity': 80,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1xJHno7SmdVtZAtXbdbDZp',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '48vIfHaK7by6x0T6ucpODL',
#   'song_name': 'Make You Mine',
#   'duration_ms': 221709,
#   'url': 'https://open.spotify.com/track/48vIfHaK7by6x0T6ucpODL',
#   'popularity': 74,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '62g7jm7YqkuQOhfhFpDQXC',
#   'artist_id': '2kRfqPViCqYdSGhYSM9R0Q'},
#  {'song_id': '0ARKW62l9uWIDYMZTUmJHF',
#   'song_name': 'Shut Down',
#   'duration_ms': 175889,
#   'url': 'https://open.spotify.com/track/0ARKW62l9uWIDYMZTUmJHF',
#   'popularity': 62,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '7jaSNQUBJbvfbZHLNFrV7P',
#   'artist_id': '41MozSoPIsD1dJM0CLPjZF'},
#  {'song_id': '17phhZDn6oGtzMe56NuWvj',
#   'song_name': 'Lose Control',
#   'duration_ms': 210688,
#   'url': 'https://open.spotify.com/track/17phhZDn6oGtzMe56NuWvj',
#   'popularity': 85,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'artist_id': '33qOK5uJ8AR2xuQQAhHump'},
#  {'song_id': '5hnGrTBaEsdukpDF6aZg8a',
#   'song_name': 'How Do I Say Goodbye',
#   'duration_ms': 163603,
#   'url': 'https://open.spotify.com/track/5hnGrTBaEsdukpDF6aZg8a',
#   'popularity': 71,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '3cptxwPFf3Ioj7I3AVX3mp',
#   'artist_id': '3QSQFmccmX81fWCUSPTS7y'},
#  {'song_id': '7ne4VBA60CxGM75vw0EYad',
#   'song_name': 'That’s So True',
#   'duration_ms': 166300,
#   'url': 'https://open.spotify.com/track/7ne4VBA60CxGM75vw0EYad',
#   'popularity': 92,
#   'song_added': '2025-01-12T15:54:09Z',
#   'album_id': '0hBRqPYPXhr1RkTDG3n4Mk',
#   'artist_id': '4tuJ0bMpJh08umKkEXKUI5'},
#  {'song_id': '7tI8dRuH2Yc6RuoTjxo4dU',
#   'song_name': 'Who',
#   'duration_ms': 170887,
#   'url': 'https://open.spotify.com/track/7tI8dRuH2Yc6RuoTjxo4dU',
#   'popularity': 86,
#   'song_added': '2025-01-12T15:55:31Z',
#   'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'artist_id': '1oSPZhvZMIrWW5I41kPkkY'},
#  {'song_id': '3rUGC1vUpkDG9CZFHMur1t',
#   'song_name': 'greedy',
#   'duration_ms': 131872,
#   'url': 'https://open.spotify.com/track/3rUGC1vUpkDG9CZFHMur1t',
#   'popularity': 82,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym'},
#  {'song_id': '5b5cPscqVEMChvDqscVw26',
#   'song_name': 'Training Season',
#   'duration_ms': 209487,
#   'url': 'https://open.spotify.com/track/5b5cPscqVEMChvDqscVw26',
#   'popularity': 77,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1Mo92916G2mmG7ajpmSVrc',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we'},
#  {'song_id': '2Ch7LmS7r2Gy2kc64wv3Bz',
#   'song_name': 'Die For You',
#   'duration_ms': 260252,
#   'url': 'https://open.spotify.com/track/2Ch7LmS7r2Gy2kc64wv3Bz',
#   'popularity': 75,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '2m6Ko3CY1qXNNja8AlugNc',
#   'song_name': 'Angel Baby',
#   'duration_ms': 220779,
#   'url': 'https://open.spotify.com/track/2m6Ko3CY1qXNNja8AlugNc',
#   'popularity': 68,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '44CdsgXhU5R2esprq0tf43',
#   'artist_id': '3WGpXCj9YhhfX11TToZcXP'},
#  {'song_id': '0O6u0VJ46W86TxN9wgyqDj',
#   'song_name': 'I Like You (A Happier Song) (with Doja Cat)',
#   'duration_ms': 192840,
#   'url': 'https://open.spotify.com/track/0O6u0VJ46W86TxN9wgyqDj',
#   'popularity': 72,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '3HHNR44YbP7XogMVwzbodx',
#   'artist_id': '246dkjvS1zLTtiykXe5h60'},
#  {'song_id': '35ovElsgyAtQwYPYnZJECg',
#   'song_name': 'Lift Me Up - From Black Panther: Wakanda Forever - Music From and Inspired By',
#   'duration_ms': 196519,
#   'url': 'https://open.spotify.com/track/35ovElsgyAtQwYPYnZJECg',
#   'popularity': 65,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '3Zzv75PyROH6AMeXN1Yr1h',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'song_id': '3xkHsmpQCBMytMJNiDf3Ii',
#   'song_name': 'Beautiful Things',
#   'duration_ms': 180304,
#   'url': 'https://open.spotify.com/track/3xkHsmpQCBMytMJNiDf3Ii',
#   'popularity': 85,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'artist_id': '22wbnEMDvgVIAGdFeek6ET'},
#  {'song_id': '1Qrg8KqiBpW07V7PNxwwwL',
#   'song_name': 'Kill Bill',
#   'duration_ms': 153946,
#   'url': 'https://open.spotify.com/track/1Qrg8KqiBpW07V7PNxwwwL',
#   'popularity': 82,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '0TRmtiR9q6XnYDzXmoMpGC',
#   'song_name': 'All My Heroes - Radio Edit',
#   'duration_ms': 228433,
#   'url': 'https://open.spotify.com/track/0TRmtiR9q6XnYDzXmoMpGC',
#   'popularity': 56,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '47ivZmuVI0HboDeCl6uOZv',
#   'artist_id': '2DYDFBqoaBP2i9XrTGpOgF'},
#  {'song_id': '5Z2MiIZ5I3jJvvmeWMLbOQ',
#   'song_name': 'Escapism.',
#   'duration_ms': 272373,
#   'url': 'https://open.spotify.com/track/5Z2MiIZ5I3jJvvmeWMLbOQ',
#   'popularity': 22,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '3omkMn8vbTKOebb9ABbqyb',
#   'artist_id': '5KKpBU5eC2tJDzf0wmlRp2'},
#  {'song_id': '0LMwmV37RCmBO2so0szAFs',
#   'song_name': 'Whatever',
#   'duration_ms': 178273,
#   'url': 'https://open.spotify.com/track/0LMwmV37RCmBO2so0szAFs',
#   'popularity': 74,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '2DoFm78vsYw31kJRzvIP4l',
#   'artist_id': '23fqKkggKUBHNkbKtXEls4'},
#  {'song_id': '6HU7h9RYOaPRFeh0R3UeAr',
#   'song_name': 'deja vu',
#   'duration_ms': 215506,
#   'url': 'https://open.spotify.com/track/6HU7h9RYOaPRFeh0R3UeAr',
#   'popularity': 80,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '6s84u2TUpR3wdUv4NgKA2j',
#   'artist_id': '1McMsnEElThX1knmY4oliG'},
#  {'song_id': '6dgUya35uo964z7GZXM07g',
#   'song_name': 'Nonsense',
#   'duration_ms': 163648,
#   'url': 'https://open.spotify.com/track/6dgUya35uo964z7GZXM07g',
#   'popularity': 81,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '5kDmlA2g9Y1YCbNo2Ufxlz',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '4q5YezDOIPcoLr8R81x9qy',
#   'song_name': 'I Can Do It With a Broken Heart',
#   'duration_ms': 218004,
#   'url': 'https://open.spotify.com/track/4q5YezDOIPcoLr8R81x9qy',
#   'popularity': 77,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1Mo4aZ8pdj6L1jx8zSwJnt',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '4l0RmWt52FxpVxMNni6i63',
#   'song_name': 'you broke me first',
#   'duration_ms': 170226,
#   'url': 'https://open.spotify.com/track/4l0RmWt52FxpVxMNni6i63',
#   'popularity': 79,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1BaHo66NCQNx6ku0hPn9bR',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym'},
#  {'song_id': '2qxmye6gAegTMjLKEBoR3d',
#   'song_name': 'Let Me Down Slowly',
#   'duration_ms': 169353,
#   'url': 'https://open.spotify.com/track/2qxmye6gAegTMjLKEBoR3d',
#   'popularity': 79,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '6jKZplJpy21R5lHaYHHjmZ',
#   'artist_id': '5IH6FPUwQTxPSXurCrcIov'},
#  {'song_id': '0rdGHLnsyAdnLcO4rz5sMK',
#   'song_name': 'Good To Be',
#   'duration_ms': 147166,
#   'url': 'https://open.spotify.com/track/0rdGHLnsyAdnLcO4rz5sMK',
#   'popularity': 57,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '6lVzd7PgdTCzmN8P9rOA0o',
#   'artist_id': '11p2E654TTU8e0nZWBR4AL'},
#  {'song_id': '4HcARAxzsbIB3MqiEkejM6',
#   'song_name': 'Locksmith',
#   'duration_ms': 164081,
#   'url': 'https://open.spotify.com/track/4HcARAxzsbIB3MqiEkejM6',
#   'popularity': 67,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1XsMFyyPhYodMoE8V0SMkl',
#   'artist_id': '0sMAHzxguan2KpnKFZPW2d'},
#  {'song_id': '2Ggr9IfS70wYQacW8nZKPG',
#   'song_name': 'labour',
#   'duration_ms': 237744,
#   'url': 'https://open.spotify.com/track/2Ggr9IfS70wYQacW8nZKPG',
#   'popularity': 71,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '4h7ERA3MzqEh9B3edziLAn',
#   'artist_id': '2EXpthNgSeTDeX8nGwxppp'},
#  {'song_id': '2GxrNKugF82CnoRFbQfzPf',
#   'song_name': 'i like the way you kiss me',
#   'duration_ms': 142514,
#   'url': 'https://open.spotify.com/track/2GxrNKugF82CnoRFbQfzPf',
#   'popularity': 79,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '5HIWDdg3g9CTOtnevKDl1z',
#   'artist_id': '0PCCGZ0wGLizHt2KZ7hhA2'},
#  {'song_id': '314fwpO5U3cwgNseLVhwdu',
#   'song_name': 'Jeanie',
#   'duration_ms': 161632,
#   'url': 'https://open.spotify.com/track/314fwpO5U3cwgNseLVhwdu',
#   'popularity': 52,
#   'song_added': '2025-02-15T00:00:00Z',
#   'album_id': '4SiEsSExMEqycC1lhRRiOY',
#   'artist_id': '1GLtl8uqKmnyCWxHmw9tL4'},
#  {'song_id': '5uQ7de4EWjb3rkcFxyEOpu',
#   'song_name': 'Belong Together',
#   'duration_ms': 148317,
#   'url': 'https://open.spotify.com/track/5uQ7de4EWjb3rkcFxyEOpu',
#   'popularity': 75,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '3PlCMwyq6nuQYtoYproV1o',
#   'artist_id': '11p2E654TTU8e0nZWBR4AL'},
#  {'song_id': '59xD5osEFsaNt5PXfIKUnX',
#   'song_name': 'Illusion',
#   'duration_ms': 188143,
#   'url': 'https://open.spotify.com/track/59xD5osEFsaNt5PXfIKUnX',
#   'popularity': 29,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '68mwSgiHv3JF9nrw9feMrt',
#   'artist_id': '6M2wZ9GZgrQXHCFfjv46we'},
#  {'song_id': '1bjeWoagtHmUKputLVyDxQ',
#   'song_name': 'Saturn',
#   'duration_ms': 186191,
#   'url': 'https://open.spotify.com/track/1bjeWoagtHmUKputLVyDxQ',
#   'popularity': 78,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1fmBMCSSkSlvxyoy1vut2k',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '1BxfuPKGuaTgP7aM0Bbdwr',
#   'song_name': 'Cruel Summer',
#   'duration_ms': 178426,
#   'url': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr',
#   'popularity': 84,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'artist_id': '06HL4z0CvFAxyc27GXpf02'},
#  {'song_id': '4Dvkj6JhhA12EX05fT7y2e',
#   'song_name': 'As It Was',
#   'duration_ms': 167303,
#   'url': 'https://open.spotify.com/track/4Dvkj6JhhA12EX05fT7y2e',
#   'popularity': 83,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'artist_id': '6KImCVD70vtIoJWnq6nGn3'},
#  {'song_id': '0mflMxspEfB0VbI1kyLiAv',
#   'song_name': 'Stick Season',
#   'duration_ms': 182346,
#   'url': 'https://open.spotify.com/track/0mflMxspEfB0VbI1kyLiAv',
#   'popularity': 82,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '50ZenUP4O2Q5eCy2NRNvuz',
#   'artist_id': '2RQXRUsr4IW1f3mKyKsy4B'},
#  {'song_id': '0WbMK4wrZ1wFSty9F7FCgu',
#   'song_name': 'Good Luck, Babe!',
#   'duration_ms': 218423,
#   'url': 'https://open.spotify.com/track/0WbMK4wrZ1wFSty9F7FCgu',
#   'popularity': 90,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'artist_id': '7GlBOeep6PqTfFi59PTUUN'},
#  {'song_id': '3Pbp7cUCx4d3OAkZSCoNvn',
#   'song_name': 'Scared To Start',
#   'duration_ms': 159636,
#   'url': 'https://open.spotify.com/track/3Pbp7cUCx4d3OAkZSCoNvn',
#   'popularity': 77,
#   'song_added': '2024-05-08T21:18:19Z',
#   'album_id': '3NpeIWhWsxU7d3XL5KEh39',
#   'artist_id': '4j96cMcT8GRi11qbvo1cLQ'},
#  {'song_id': '28mTF5uRWpndySLabPPTZL',
#   'song_name': 'Alibi - Tiësto Remix',
#   'duration_ms': 178125,
#   'url': 'https://open.spotify.com/track/28mTF5uRWpndySLabPPTZL',
#   'popularity': 60,
#   'song_added': '2024-12-01T23:25:57Z',
#   'album_id': '2Zh6Oz9pR5zYF3vEno5jV5',
#   'artist_id': '5MraexJKZDrQYzS98kNwie'},
#  {'song_id': '3U3hFkMr0Q90pD24EkE3Pr',
#   'song_name': 'BMF',
#   'duration_ms': 180746,
#   'url': 'https://open.spotify.com/track/3U3hFkMr0Q90pD24EkE3Pr',
#   'popularity': 85,
#   'song_added': '2025-01-12T16:04:00Z',
#   'album_id': '3VQkNrG74QPY4rHBPoyZYZ',
#   'artist_id': '7tYKF4w9nC0nq9CsPZTHyP'},
#  {'song_id': '4lriIG2vNqwDWzOj2I9rtj',
#   'song_name': 'Ma Meilleure Ennemie (from the series Arcane League of Legends)',
#   'duration_ms': 147973,
#   'url': 'https://open.spotify.com/track/4lriIG2vNqwDWzOj2I9rtj',
#   'popularity': 79,
#   'song_added': '2025-01-12T16:05:26Z',
#   'album_id': '3ZZlKPrWKSVI28zT3AGLQB',
#   'artist_id': '5j4HeCoUlzhfWtjAfM1acR'},
#  {'song_id': '3dj4wgM3cPeuLwMNHDuBon',
#   'song_name': 'The Door',
#   'duration_ms': 212648,
#   'url': 'https://open.spotify.com/track/3dj4wgM3cPeuLwMNHDuBon',
#   'popularity': 83,
#   'song_added': '2025-01-12T16:16:49Z',
#   'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'artist_id': '33qOK5uJ8AR2xuQQAhHump'}]

# %%
# creating a dataframe from all the information we have so far for album, artists, and the song.
album_df = pd.DataFrame.from_dict(album_list)
album_df.head()
# Out:
#                  album_id                           name release_date  \
# 0  10FLjwfpbxLmW8c25Xyc2N               Die With A Smile   2024-08-16
# 1  2IYQwwgxgOIn7t3iF6ufFD                           APT.   2024-10-18
# 2  5quMTd5zeI9yW5UDua8wS4                       Espresso   2024-04-12
# 3  5EYKrEDnKhhcNxGedaRQeK               eternal sunshine   2024-03-08
# 4  1Mo4aZ8pdj6L1jx8zSwJnt  THE TORTURED POETS DEPARTMENT   2024-04-18
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1             1  https://open.spotify.com/album/2IYQwwgxgOIn7t3...
# 2             1  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 3            13  https://open.spotify.com/album/5EYKrEDnKhhcNxG...
# 4            16  https://open.spotify.com/album/1Mo4aZ8pdj6L1jx...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      51 non-null     object
#  1   name          51 non-null     object
#  2   release_date  51 non-null     object
#  3   total_tracks  51 non-null     int64
#  4   url           51 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
# changing the dtype of album_release_date fro object to datetime
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      51 non-null     object
#  1   name          51 non-null     object
#  2   release_date  51 non-null     datetime64[ns]
#  3   total_tracks  51 non-null     int64
#  4   url           51 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
album_df.count()
# Out:
# album_id        51
# name            51
# release_date    51
# total_tracks    51
# url             51
# dtype: int64

# %%
# Remove duplicate album entries based on the `album_id` column.  
# - `drop_duplicates()` ensures that only unique album IDs remain.  
# - The `subset=['album_id']` parameter specifies that duplicates are identified based on album ID.  
# - This prevents redundant album records in the DataFrame.  

album_df = album_df.drop_duplicates(subset=['album_id'])

# The function drop_duplicates() removes duplicate rows from a DataFrame.
# By default, it checks all columns to identify duplicates.
# When subset=['album_id'] is specified, it only considers the album_id column to determine duplicates.

# %%
album_df.count()
# Out:
# album_id        49
# name            49
# release_date    49
# total_tracks    49
# url             49
# dtype: int64

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                 artist_id               name  \
# 0  1HY2Jd0NmPuamShAr6KMms          Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C         Bruno Mars
# 2  3eVa5w3URK5duf6eyVDbu9               ROSÉ
# 3  0du5cEVh5yTK9QJze8zA0C         Bruno Mars
# 4  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
#
#                                                  url
# 0  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 3  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 4  https://api.spotify.com/v1/artists/74KM79TiuVK...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])
artist_df.head()
# Out:
#                 artist_id               name  \
# 0  1HY2Jd0NmPuamShAr6KMms          Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C         Bruno Mars
# 2  3eVa5w3URK5duf6eyVDbu9               ROSÉ
# 4  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 5  66CXWjxzNUsdJxJ2JdwvnR      Ariana Grande
#
#                                                  url
# 0  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 4  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 5  https://api.spotify.com/v1/artists/66CXWjxzNUs...

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df.head()
# Out:
#                   song_id                                 song_name  \
# 0  2plbrEY59IikOBgBGLjaoe                          Die With A Smile
# 1  5vNRhkKd0yEAg8suGBpjeY                                      APT.
# 2  2qSkIjg1o9h3YT9RAgYN75                                  Espresso
# 3  51ZQ1vr10ffzbwIjDCwqm4  we can't be friends (wait for your love)
# 4  2OzhQlSqBEmt7hmkYxfT6m             Fortnight (feat. Post Malone)
#
#    duration_ms                                                url  popularity  \
# 0       251667  https://open.spotify.com/track/2plbrEY59IikOBg...          96
# 1       169917  https://open.spotify.com/track/5vNRhkKd0yEAg8s...          91
# 2       175459  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          84
# 3       228639  https://open.spotify.com/track/51ZQ1vr10ffzbwI...          83
# 4       228965  https://open.spotify.com/track/2OzhQlSqBEmt7hm...          79
#
#              song_added                album_id               artist_id
# 0  2024-10-04T14:54:56Z  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# 1  2024-12-01T23:23:05Z  2IYQwwgxgOIn7t3iF6ufFD  3eVa5w3URK5duf6eyVDbu9
# 2  2024-05-08T21:18:19Z  5quMTd5zeI9yW5UDua8wS4  74KM79TiuVKeVCqs8QtB0B
# 3  2024-05-08T21:18:19Z  5EYKrEDnKhhcNxGedaRQeK  66CXWjxzNUsdJxJ2JdwvnR
# 4  2024-05-08T21:18:19Z  1Mo4aZ8pdj6L1jx8zSwJnt  06HL4z0CvFAxyc27GXpf02

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])
song_df.head()
# Out:
#                   song_id                                 song_name  \
# 0  2plbrEY59IikOBgBGLjaoe                          Die With A Smile
# 1  5vNRhkKd0yEAg8suGBpjeY                                      APT.
# 2  2qSkIjg1o9h3YT9RAgYN75                                  Espresso
# 3  51ZQ1vr10ffzbwIjDCwqm4  we can't be friends (wait for your love)
# 4  2OzhQlSqBEmt7hmkYxfT6m             Fortnight (feat. Post Malone)
#
#    duration_ms                                                url  popularity  \
# 0       251667  https://open.spotify.com/track/2plbrEY59IikOBg...          96
# 1       169917  https://open.spotify.com/track/5vNRhkKd0yEAg8s...          91
# 2       175459  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          84
# 3       228639  https://open.spotify.com/track/51ZQ1vr10ffzbwI...          83
# 4       228965  https://open.spotify.com/track/2OzhQlSqBEmt7hm...          79
#
#              song_added                album_id               artist_id
# 0  2024-10-04T14:54:56Z  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# 1  2024-12-01T23:23:05Z  2IYQwwgxgOIn7t3iF6ufFD  3eVa5w3URK5duf6eyVDbu9
# 2  2024-05-08T21:18:19Z  5quMTd5zeI9yW5UDua8wS4  74KM79TiuVKeVCqs8QtB0B
# 3  2024-05-08T21:18:19Z  5EYKrEDnKhhcNxGedaRQeK  66CXWjxzNUsdJxJ2JdwvnR
# 4  2024-05-08T21:18:19Z  1Mo4aZ8pdj6L1jx8zSwJnt  06HL4z0CvFAxyc27GXpf02

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      51 non-null     object
#  1   song_name    51 non-null     object
#  2   duration_ms  51 non-null     int64
#  3   url          51 non-null     object
#  4   popularity   51 non-null     int64
#  5   song_added   51 non-null     object
#  6   album_id     51 non-null     object
#  7   artist_id    51 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %%
# change the dtype of song_added from object to datetime.
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      51 non-null     object
#  1   song_name    51 non-null     object
#  2   duration_ms  51 non-null     int64
#  3   url          51 non-null     object
#  4   popularity   51 non-null     int64
#  5   song_added   51 non-null     datetime64[ns, UTC]
#  6   album_id     51 non-null     object
#  7   artist_id    51 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
